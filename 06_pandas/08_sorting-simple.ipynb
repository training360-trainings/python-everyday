# %%
import pandas as pd

# %%
df_survey = pd.read_csv(
    '../files/survey_results_public.csv', index_col='Respondent')

# %%
df_schema = pd.read_csv(
    '../files/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 100)

# %%
df_survey
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
# ...               ...      ...        ...            ...                 ...
# 64858              16      NaN        NaN            NaN       United States
# 64867             NaN      NaN        NaN            NaN             Morocco
# 64898             NaN      NaN        NaN            NaN            Viet Nam
# 64925             NaN      NaN        NaN            NaN              Poland
# 65112             NaN      NaN        NaN            NaN               Spain
#
#               CurrencyDesc CurrencySymbol  \
# Respondent
# 1            European Euro            EUR
# 2           Pound sterling            GBP
# 3                      NaN            NaN
# 4             Albanian lek            ALL
# 5                      NaN            NaN
# ...                    ...            ...
# 64858                  NaN            NaN
# 64867                  NaN            NaN
# 64898                  NaN            NaN
# 64925                  NaN            NaN
# 65112                  NaN            NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                        Microsoft SQL Server
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                            MySQL;PostgreSQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                                                     NaN
# 64925         DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 65112                            MariaDB;Microsoft SQL Server
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1                   Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                               MySQL;PostgreSQL;Redis;SQLite
# ...                                                       ...
# 64858                                                     NaN
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                                                     NaN
# 64925                                                  Oracle
# 65112               MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 64858                                     Senior executive/VP
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 64858       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64867                                                   NaN
# 64898                             Primary/elementary school
# 64925                                                   NaN
# 65112            Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
# ...                                                       ...
# 64858                                      Employed full-time
# 64867                                      Employed full-time
# 64898                                                     NaN
# 64925                                      Employed full-time
# 65112                                      Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
# ...                                  ...    ...
# 64858                                NaN    NaN
# 64867                                NaN    NaN
# 64898                                NaN    NaN
# 64925                                NaN    NaN
# 65112                                NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
# ...                           ...
# 64858                         NaN
# 64867                         NaN
# 64898                         NaN
# 64925                         NaN
# 65112                         NaN
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                                Python;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                                HTML/CSS
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# ...                                      ...                ...
# 64858                                    NaN                NaN
# 64867                                    NaN                NaN
# 64898                                    NaN                NaN
# 64925                                Node.js                NaN
# 65112                      .NET Core;Xamarin     .NET;.NET Core
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                Github;Gitlab
# 65112                       Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                       ...       ...
# 64858                                                     NaN       NaN
# 64867                                                     NaN       NaN
# 64898                                                     NaN       NaN
# 64925                   Confluence;Jira;Slack;Microsoft Teams       NaN
# 65112                                                  Github       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
# ...                        ...                                 ...
# 64858                      NaN                      Very important
# 64867                      NaN                                 NaN
# 64898                      NaN                                 NaN
# 64925                      NaN                                 NaN
# 65112                      NaN                Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
# ...                       ...            ...         ...            ...
# 64858                     NaN  Once a decade         NaN            NaN
# 64867                     NaN            NaN         NaN            NaN
# 64898                     NaN            NaN         NaN            NaN
# 64925                     NaN    Once a year         NaN            NaN
# 65112                     NaN    Once a year         NaN            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
# ...                  ...                                                ...
# 64858                NaN                                                NaN
# 64867                NaN                                                NaN
# 64898                NaN                                                NaN
# 64925                NaN                                                NaN
# 65112                NaN                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# ...                                                       ...
# 64858                                      Start a free trial
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                      Start a free trial
# 65112       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# ...                       ...
# 64858                  Amused
# 64867                     NaN
# 64898                     NaN
# 64925       Hello, old friend
# 65112             Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64858        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
# 64898                                                     NaN
# 64925        Stack Overflow (public Q&A for anyone who codes)
# 65112                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 64858                               Call a coworker or friend      Windows
# 64867                                                     NaN          NaN
# 64898                                                     NaN          NaN
# 64925          Call a coworker or friend;Visit Stack Overflow      Windows
# 65112       Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
# ...                              ...
# 64858                            NaN
# 64867                            NaN
# 64898                            NaN
# 64925                            NaN
# 65112                            NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                      Arduino;Linux;Raspberry Pi;Windows
#
#                                     PlatformWorkedWith  \
# Respondent
# 1                                              Windows
# 2                                                  iOS
# 3                                                  NaN
# 4                                                  NaN
# 5                       AWS;Docker;Linux;MacOS;Windows
# ...                                                ...
# 64858                                              NaN
# 64867                                              NaN
# 64898                                              NaN
# 64925                                    Linux;Windows
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# ...                                      ...                      ...
# 64858                                    NaN                      NaN
# 64867                                    NaN                      NaN
# 64898                                    NaN                      NaN
# 64925                                    NaN                      NaN
# 65112                                    NaN                      NaN
#
#            SOAccount           SOComm                           SOPartFreq  \
# Respondent
# 1                 No   No, not at all                                  NaN
# 2                Yes  Yes, definitely  Less than once per month or monthly
# 3                Yes    Yes, somewhat      A few times per month or weekly
# 4                Yes  Yes, definitely      A few times per month or weekly
# 5                Yes    Yes, somewhat  Less than once per month or monthly
# ...              ...              ...                                  ...
# 64858            NaN              NaN                                  NaN
# 64867            NaN              NaN                                  NaN
# 64898            NaN              NaN                                  NaN
# 64925            NaN              NaN                                  NaN
# 65112            NaN              NaN                                  NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# ...                                     ...                         ...
# 64858                                   NaN                         NaN
# 64867                                   NaN                         NaN
# 64898                                   NaN                         NaN
# 64925                                   NaN                         NaN
# 65112                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# ...                           ...   ...
# 64858                         NaN   NaN
# 64867                         NaN   NaN
# 64898                         NaN   NaN
# 64925                         NaN   NaN
# 65112                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                  WebframeDesireNextYear  \
# Respondent
# 1                          ASP.NET Core
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                  Django;Ruby on Rails
# ...                                 ...
# 64858                               NaN
# 64867                               NaN
# 64898                               NaN
# 64925       Angular;Angular.js;React.js
# 65112               ASP.NET Core;jQuery
#
#                                 WebframeWorkedWith  \
# Respondent
# 1                             ASP.NET;ASP.NET Core
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                    Ruby on Rails
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                          NaN
# 65112       Angular;Angular.js;ASP.NET Core;jQuery
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# ...                                              ...          ...       ...
# 64858                                            NaN          NaN        10
# 64867                                            NaN          NaN       NaN
# 64898                                            NaN          NaN       NaN
# 64925                                            NaN          NaN       NaN
# 65112                                            NaN          NaN       NaN
#
#                 YearsCodePro
# Respondent
# 1                         27
# 2                          4
# 3                        NaN
# 4                          4
# 5                          8
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
filter_high_salary = df_survey['ConvertedComp'] > 70000

# %%
df_survey.loc[filter_high_salary]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# ...                                                       ...      ...   ...
# 65586                          I am a developer by profession      Yes   NaN
# 65589                          I am a developer by profession      Yes   NaN
# 65602       I am not primarily a developer, but I write co...      Yes   NaN
# 65604                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# Respondent
# 8                  12   Yearly   116000.0       116000.0   United States
# 16                  8  Monthly     7000.0       108576.0  United Kingdom
# 17                 14   Yearly    79000.0        79000.0   United States
# 18                 12  Monthly   105000.0      1260000.0   United States
# 19                 15   Yearly    83400.0        83400.0   United States
# ...               ...      ...        ...            ...             ...
# 65586               8   Yearly   225000.0       225000.0   United States
# 65589              16   Yearly   150000.0       150000.0   United States
# 65602              13   Yearly   140000.0       140000.0   United States
# 65604              13   Weekly     3000.0       150000.0   United States
# 65617              15   Yearly   120000.0       129718.0         Germany
#
#                     CurrencyDesc CurrencySymbol  \
# Respondent
# 8           United States dollar            USD
# 16                Pound sterling            GBP
# 17          United States dollar            USD
# 18          United States dollar            USD
# 19          United States dollar            USD
# ...                          ...            ...
# 65586       United States dollar            USD
# 65589       United States dollar            USD
# 65602       United States dollar            USD
# 65604       United States dollar            USD
# 65617              European Euro            EUR
#
#                                       DatabaseDesireNextYear  \
# Respondent
# 8                                                    MongoDB
# 16                                                       NaN
# 17          Cassandra;Elasticsearch;MariaDB;PostgreSQL;Redis
# 18                     Elasticsearch;PostgreSQL;Redis;SQLite
# 19                                           MariaDB;MongoDB
# ...                                                      ...
# 65586                                                    NaN
# 65589                                                    NaN
# 65602                                                    NaN
# 65604                                                    NaN
# 65617                                                    NaN
#
#                                   DatabaseWorkedWith  \
# Respondent
# 8                                MariaDB;MySQL;Redis
# 16                                        PostgreSQL
# 17                   Microsoft SQL Server;PostgreSQL
# 18          Elasticsearch;MariaDB;MySQL;Redis;SQLite
# 19                      MariaDB;Microsoft SQL Server
# ...                                              ...
# 65586                                            NaN
# 65589                                            NaN
# 65602                                            NaN
# 65604                                            NaN
# 65617                                            NaN
#
#                                                       DevType  \
# Respondent
# 8           Developer, back-end;Developer, desktop or ente...
# 16          Database administrator;Developer, back-end;Dev...
# 17                                      Developer, full-stack
# 18                                        Developer, back-end
# 19                                      Developer, full-stack
# ...                                                       ...
# 65586       Developer, back-end;Developer, desktop or ente...
# 65589               Developer, back-end;Developer, full-stack
# 65602       Data or business analyst;Data scientist or mac...
# 65604                           Academic researcher;Scientist
# 65617       Database administrator;Developer, back-end;Dev...
#
#                                                       EdLevel  \
# Respondent
# 8                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 18               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 65586       Some college/university study without earning ...
# 65589            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65602              Other doctoral degree (Ph.D., Ed.D., etc.)
# 65604         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65617         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# Respondent
# 8                                          Employed full-time
# 16          Independent contractor, freelancer, or self-em...
# 17                                         Employed full-time
# 18                                         Employed full-time
# 19                                         Employed full-time
# ...                                                       ...
# 65586                                      Employed full-time
# 65589                                      Employed full-time
# 65602                                      Employed full-time
# 65604                                      Employed full-time
# 65617       Independent contractor, freelancer, or self-em...
#
#                                Ethnicity Gender  \
# Respondent
# 8           White or of European descent    Man
# 16          White or of European descent    Man
# 17          White or of European descent    Man
# 18          White or of European descent    Man
# 19          White or of European descent    Man
# ...                                  ...    ...
# 65586                                NaN    NaN
# 65589                                NaN    NaN
# 65602                                NaN    NaN
# 65604                                NaN    NaN
# 65617                                NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 8           Remote work options;Opportunities for professi...
# 16          Industry that I’d be working in;Diversity of t...
# 17          Industry that I’d be working in;Languages, fra...
# 18          Languages, frameworks, and other technologies ...
# 19          Flex time or a flexible schedule;Office enviro...
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                            JobSat  \
# Respondent
# 8           Slightly dissatisfied
# 16                 Very satisfied
# 17          Slightly dissatisfied
# 18                 Very satisfied
# 19          Slightly dissatisfied
# ...                           ...
# 65586              Very satisfied
# 65589              Very satisfied
# 65602              Very satisfied
# 65604          Slightly satisfied
# 65617              Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 8           I’m not actively looking, but I am open to new...
# 16          I’m not actively looking, but I am open to new...
# 17          I’m not actively looking, but I am open to new...
# 18               I am not interested in new job opportunities
# 19          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8                                                  JavaScript
# 16                                                         Go
# 17          C#;Go;Haskell;HTML/CSS;JavaScript;Python;Ruby;...
# 18                                              HTML/CSS;Perl
# 19                                    C#;Go;Python;TypeScript
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 8                                                  Python;SQL
# 16          Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17                      C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18                        Bash/Shell/PowerShell;HTML/CSS;Perl
# 19          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                                  MiscTechDesireNextYear  \
# Respondent
# 8                                              Unity 3D
# 16                                                  NaN
# 17                                   .NET Core;Teraform
# 18                                                  NaN
# 19          Node.js;React Native;Unity 3D;Unreal Engine
# ...                                                 ...
# 65586                                               NaN
# 65589                                               NaN
# 65602                                               NaN
# 65604                                               NaN
# 65617                                               NaN
#
#                 MiscTechWorkedWith  \
# Respondent
# 8                          Ansible
# 16                             NaN
# 17                    .NET;Node.js
# 18                             NaN
# 19          .NET;.NET Core;Node.js
# ...                            ...
# 65586                          NaN
# 65589                          NaN
# 65602                          NaN
# 65604                          NaN
# 65617                          NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 8                                                         NaN
# 16                                                        NaN
# 17          Github;Gitlab;Slack;Google Suite (Docs, Meet, ...
# 18                                                     Github
# 19                                               Github;Slack
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 8           Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 16          Github;Slack;Google Suite (Docs, Meet, etc);St...        No
# 17          Github;Gitlab;Slack;Microsoft Teams;Google Sui...       Yes
# 18                                               Github;Slack  Not sure
# 19                               Confluence;Jira;Github;Slack       Yes
# ...                                                       ...       ...
# 65586                                                     NaN  Not sure
# 65589                                                     NaN        No
# 65602                                                     NaN       NaN
# 65604                                                     NaN        No
# 65617                                                     NaN       Yes
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 8           Extremely important  Not at all important/not necessary
# 16          Extremely important                    Fairly important
# 17          Extremely important                    Fairly important
# 18                      Neutral                      Very important
# 19          Extremely important                    Fairly important
# ...                         ...                                 ...
# 65586       Extremely important                      Very important
# 65589        Somewhat important                    Fairly important
# 65602                       NaN                    Fairly important
# 65604        Somewhat important                Critically important
# 65617       Extremely important                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 8           Curious about other opportunities;Better compe...
# 16          Having a bad day (or week or month) at work;Cu...
# 17          Having a bad day (or week or month) at work;Be...
# 18                                        Looking to relocate
# 19          Having a bad day (or week or month) at work;Tr...
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 8           Read company media, such as employee blogs or ...
# 16          Personal network - friends or family;Directly ...
# 17          Company reviews from third party sites (e.g. G...
# 18                                                        NaN
# 19          Company reviews from third party sites (e.g. G...
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 8                    Once a year    Not sure                           Yes
# 16                   Once a year    Not sure                           Yes
# 17                   Once a year    Not sure                            No
# 18          Once every few years         Yes  Onboarding? What onboarding?
# 19                   Once a year         Yes                            No
# ...                          ...         ...                           ...
# 65586                        NaN         NaN                           Yes
# 65589                        NaN         NaN  Onboarding? What onboarding?
# 65602                        NaN         NaN                           NaN
# 65604                        NaN         NaN                           Yes
# 65617                        NaN    Not sure  Onboarding? What onboarding?
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 8                     No  Occasionally: 1-2 days per quarter but less th...
# 16                    No                   Often: 1-2 days per week or more
# 17                    No                  Rarely: 1-2 days per year or less
# 18                   Yes  Occasionally: 1-2 days per quarter but less th...
# 19                    No  Occasionally: 1-2 days per quarter but less th...
# ...                  ...                                                ...
# 65586                NaN  Sometimes: 1-2 days per month but less than we...
# 65589                NaN  Occasionally: 1-2 days per quarter but less th...
# 65602                NaN                                                NaN
# 65604                NaN  Occasionally: 1-2 days per quarter but less th...
# 65617                Yes                   Often: 1-2 days per week or more
#
#                                           NEWPurchaseResearch  \
# Respondent
# 8           Start a free trial;Ask developers I know/work ...
# 16          Ask developers I know/work with;Visit develope...
# 17                                                        NaN
# 18          Start a free trial;Ask developers I know/work ...
# 19                                                        NaN
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                 NEWPurpleLink  \
# Respondent
# 8           Hello, old friend
# 16          Hello, old friend
# 17          Hello, old friend
# 18          Hello, old friend
# 19          Hello, old friend
# ...                       ...
# 65586                     NaN
# 65589                     NaN
# 65602                     NaN
# 65604                     NaN
# 65617                     NaN
#
#                                                    NEWSOSites  \
# Respondent
# 8           Stack Overflow (public Q&A for anyone who code...
# 16          Stack Overflow (public Q&A for anyone who code...
# 17          Stack Overflow (public Q&A for anyone who code...
# 18          Stack Overflow (public Q&A for anyone who code...
# 19          Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 8           Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 16          Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 17          Call a coworker or friend;Visit Stack Overflow...      Windows
# 18          Play games;Visit Stack Overflow;Do other work ...  Linux-based
# 19          Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 65586                                                     NaN          NaN
# 65589                                                     NaN          NaN
# 65602                                                     NaN          NaN
# 65604                                                     NaN          NaN
# 65617                                                     NaN          NaN
#
#                                                       OrgSize  \
# Respondent
# 8                                          20 to 99 employees
# 16          Just me - I am a freelancer, sole proprietor, ...
# 17                                         20 to 99 employees
# 18                                       100 to 499 employees
# 19                                   10,000 or more employees
# ...                                                       ...
# 65586                                1,000 to 4,999 employees
# 65589                                      20 to 99 employees
# 65602                                10,000 or more employees
# 65604                                10,000 or more employees
# 65617       Just me - I am a freelancer, sole proprietor, ...
#
#                        PlatformDesireNextYear  \
# Respondent
# 8             iOS;Slack Apps and Integrations
# 16                                        NaN
# 17          Docker;Kubernetes;Microsoft Azure
# 18                                      Linux
# 19            iOS;Slack Apps and Integrations
# ...                                       ...
# 65586                                     NaN
# 65589                                     NaN
# 65602                                     NaN
# 65604                                     NaN
# 65617                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                                                      Docker
# 16          AWS;Docker;Google Cloud Platform;Heroku;Kubern...
# 17                                                        NaN
# 18                                                  AWS;Linux
# 19                                                    Windows
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 8                   I have some influence  Straight / Heterosexual       Yes
# 16                                    NaN  Straight / Heterosexual       Yes
# 17          I have little or no influence  Straight / Heterosexual       Yes
# 18                  I have some influence  Straight / Heterosexual       Yes
# 19          I have little or no influence  Straight / Heterosexual       Yes
# ...                                   ...                      ...       ...
# 65586                                 NaN                      NaN       NaN
# 65589                                 NaN                      NaN       NaN
# 65602                                 NaN                      NaN       NaN
# 65604                                 NaN                      NaN       NaN
# 65617                                 NaN                      NaN       Yes
#
#                     SOComm                                         SOPartFreq  \
# Respondent
# 8           No, not really                Less than once per month or monthly
# 16           Yes, somewhat                             Multiple times per day
# 17          No, not at all  I have never participated in Q&A on Stack Over...
# 18           Yes, somewhat  I have never participated in Q&A on Stack Over...
# 19                 Neutral                Less than once per month or monthly
# ...                    ...                                                ...
# 65586                  NaN                                                NaN
# 65589                  NaN                                                NaN
# 65602                  NaN                                                NaN
# 65604                  NaN                                                NaN
# 65617              Neutral                Less than once per month or monthly
#
#                        SOVisitFreq                  SurveyEase  \
# Respondent
# 8           Multiple times per day                        Easy
# 16          Multiple times per day                        Easy
# 17           Daily or almost daily                        Easy
# 18           Daily or almost daily  Neither easy nor difficult
# 19            A few times per week                        Easy
# ...                            ...                         ...
# 65586                          NaN                         NaN
# 65589                          NaN                         NaN
# 65602                          NaN                         NaN
# 65604                          NaN                         NaN
# 65617        Daily or almost daily                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 8           Appropriate in length    No
# 16          Appropriate in length    No
# 17          Appropriate in length    No
# 18          Appropriate in length    No
# 19          Appropriate in length    No
# ...                           ...   ...
# 65586                         NaN   NaN
# 65589                         NaN   NaN
# 65602                         NaN   NaN
# 65604                         NaN   NaN
# 65617                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 16          Computer science, computer engineering, or sof...
# 17          Computer science, computer engineering, or sof...
# 18          Computer science, computer engineering, or sof...
# 19          Computer science, computer engineering, or sof...
# ...                                                       ...
# 65586                               Mathematics or statistics
# 65589       Computer science, computer engineering, or sof...
# 65602       Another engineering discipline (such as civil,...
# 65604       Computer science, computer engineering, or sof...
# 65617       Another engineering discipline (such as civil,...
#
#                          WebframeDesireNextYear  \
# Respondent
# 8                        Django;React.js;Vue.js
# 16                                          NaN
# 17          ASP.NET Core;Gatsby;React.js;Vue.js
# 18                                          NaN
# 19                      Django;Express;React.js
# ...                                         ...
# 65586                                       NaN
# 65589                                       NaN
# 65602                                       NaN
# 65604                                       NaN
# 65617                                       NaN
#
#                                WebframeWorkedWith  \
# Respondent
# 8                                           Flask
# 16                                jQuery;React.js
# 17          ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 18                                            NaN
# 19                Angular;Angular.js;ASP.NET Core
# ...                                           ...
# 65586                                         NaN
# 65589                                         NaN
# 65602                                         NaN
# 65604                                         NaN
# 65617                                         NaN
#
#                                       WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 8           Just as welcome now as I felt last year         39.0        17
# 16          Just as welcome now as I felt last year         50.0        37
# 17          Just as welcome now as I felt last year         40.0         7
# 18          Just as welcome now as I felt last year         45.0        19
# 19          Just as welcome now as I felt last year         35.0         9
# ...                                             ...          ...       ...
# 65586                                           NaN         50.0        25
# 65589                                           NaN         45.0        10
# 65602                                           NaN          NaN        15
# 65604                                           NaN         45.0         7
# 65617       Just as welcome now as I felt last year         35.0         9
#
#            YearsCodePro
# Respondent
# 8                    13
# 16                   23
# 17                    3
# 18                   12
# 19                    3
# ...                 ...
# 65586                15
# 65589                 6
# 65602                12
# 65604                 4
# 65617                 9
#
# [13178 rows x 60 columns]

# %%
df_survey.loc[filter_high_salary].sort_values(
    by='ConvertedComp', ascending=False)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 29260       I am a developer by profession      Yes  51.0         16   Weekly
# 33865       I am a developer by profession      Yes  35.0         15  Monthly
# 16018       I am a developer by profession      Yes  23.0         18   Weekly
# 193         I am a developer by profession      Yes  29.0         16   Weekly
# 3948        I am a developer by profession      Yes  25.0         18   Weekly
# ...                                    ...      ...   ...        ...      ...
# 21657       I am a developer by profession      Yes  19.0         12  Monthly
# 29429       I am a developer by profession      Yes  33.0         10  Monthly
# 44018       I am a developer by profession      Yes  42.0         17  Monthly
# 5459        I am a developer by profession      Yes  31.0        NaN   Yearly
# 58883       I am a developer by profession      Yes   NaN         12   Yearly
#
#             CompTotal  ConvertedComp        Country          CurrencyDesc  \
# Respondent
# 29260        172000.0      2000000.0  United States  United States dollar
# 33865        250000.0      2000000.0  United States  United States dollar
# 16018         82000.0      2000000.0  United States  United States dollar
# 193          120000.0      2000000.0  United States  United States dollar
# 3948          70000.0      2000000.0  United States  United States dollar
# ...               ...            ...            ...                   ...
# 21657          5400.0        70044.0        Germany         European Euro
# 29429         20000.0        70044.0         Israel    Israeli new shekel
# 44018          2200.0        70020.0        Bahrain        Bahraini dinar
# 5459         104800.0        70017.0      Australia     Australian dollar
# 58883         70008.0        70008.0  United States  United States dollar
#
#            CurrencySymbol                             DatabaseDesireNextYear  \
# Respondent
# 29260                 USD  Elasticsearch;IBM DB2;Microsoft SQL Server;Mon...
# 33865                 USD                                      MongoDB;Redis
# 16018                 USD                                                NaN
# 193                   USD                                                NaN
# 3948                  USD                              MariaDB;MongoDB;Redis
# ...                   ...                                                ...
# 21657                 EUR                 MariaDB;Microsoft SQL Server;MySQL
# 29429                 ILS                 Elasticsearch;Firebase;MySQL;Redis
# 44018                 BHD  Elasticsearch;IBM DB2;MariaDB;Microsoft SQL Se...
# 5459                  AUD                Microsoft SQL Server;MongoDB;Oracle
# 58883                 USD                                   Firebase;MongoDB
#
#                                            DatabaseWorkedWith  \
# Respondent
# 29260       IBM DB2;Microsoft SQL Server;MongoDB;MySQL;SQLite
# 33865                                MongoDB;PostgreSQL;Redis
# 16018                                        PostgreSQL;Redis
# 193                                                       NaN
# 3948        MariaDB;Microsoft SQL Server;MongoDB;MySQL;Ora...
# ...                                                       ...
# 21657                      MariaDB;Microsoft SQL Server;MySQL
# 29429                                                   MySQL
# 44018               IBM DB2;Microsoft SQL Server;Oracle;Redis
# 5459                                                   Oracle
# 58883                                    Microsoft SQL Server
#
#                                                       DevType  \
# Respondent
# 29260       Designer;Developer, back-end;Developer, deskto...
# 33865       Developer, back-end;Developer, front-end;Devel...
# 16018                                     Developer, back-end
# 193                                         Developer, mobile
# 3948        Data or business analyst;Data scientist or mac...
# ...                                                       ...
# 21657       Database administrator;Developer, back-end;Dev...
# 29429       Data scientist or machine learning specialist;...
# 44018       Designer;Developer, back-end;Developer, deskto...
# 5459                                    Developer, full-stack
# 58883       Developer, desktop or enterprise applications;...
#
#                                                       EdLevel  \
# Respondent
# 29260            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33865            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16018            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 193           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3948        Secondary school (e.g. American high school, G...
# ...                                                       ...
# 21657            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 29429            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44018            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5459             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58883            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                     Employment                                    Ethnicity  \
# Respondent
# 29260       Employed full-time                 White or of European descent
# 33865       Employed full-time                 White or of European descent
# 16018       Employed full-time                                          NaN
# 193         Employed full-time                 White or of European descent
# 3948        Employed full-time                 White or of European descent
# ...                        ...                                          ...
# 21657       Employed full-time                 White or of European descent
# 29429       Employed full-time  Middle Eastern;White or of European descent
# 44018       Employed full-time                                          NaN
# 5459        Employed full-time                 White or of European descent
# 58883       Employed full-time                 White or of European descent
#
#            Gender                                         JobFactors  \
# Respondent
# 29260       Woman  Flex time or a flexible schedule;Languages, fr...
# 33865         Man  Languages, frameworks, and other technologies ...
# 16018         Man  Flex time or a flexible schedule;Remote work o...
# 193           Man  Specific department or team I’d be working on;...
# 3948          Man  Languages, frameworks, and other technologies ...
# ...           ...                                                ...
# 21657         Man  Diversity of the company or organization;Langu...
# 29429         Man  Flex time or a flexible schedule;Specific depa...
# 44018         Man  Remote work options;Office environment or comp...
# 5459          Man  How widely used or impactful my work output wo...
# 58883         Man  Industry that I’d be working in;Languages, fra...
#
#                                         JobSat  \
# Respondent
# 29260                           Very satisfied
# 33865                       Slightly satisfied
# 16018                       Slightly satisfied
# 193                             Very satisfied
# 3948                            Very satisfied
# ...                                        ...
# 21657                           Very satisfied
# 29429                       Slightly satisfied
# 44018       Neither satisfied nor dissatisfied
# 5459                     Slightly dissatisfied
# 58883                    Slightly dissatisfied
#
#                                                       JobSeek  \
# Respondent
# 29260       I’m not actively looking, but I am open to new...
# 33865       I’m not actively looking, but I am open to new...
# 16018       I’m not actively looking, but I am open to new...
# 193         I’m not actively looking, but I am open to new...
# 3948        I’m not actively looking, but I am open to new...
# ...                                                       ...
# 21657            I am not interested in new job opportunities
# 29429            I am not interested in new job opportunities
# 44018       I’m not actively looking, but I am open to new...
# 5459        I’m not actively looking, but I am open to new...
# 58883                         I am actively looking for a job
#
#                                        LanguageDesireNextYear  \
# Respondent
# 29260       Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 33865                                    Go;Python;TypeScript
# 16018                                         C#;Python;Swift
# 193                                         Objective-C;Swift
# 3948              Dart;Go;HTML/CSS;JavaScript;Rust;TypeScript
# ...                                                       ...
# 21657        Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;PHP
# 29429                                                  Python
# 44018               C#;C++;HTML/CSS;JavaScript;SQL;TypeScript
# 5459                          C#;JavaScript;Python;TypeScript
# 58883                                        C#;Kotlin;Python
#
#                                            LanguageWorkedWith  \
# Respondent
# 29260       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 33865       Bash/Shell/PowerShell;Go;Java;JavaScript;Pytho...
# 16018                                                    Java
# 193                         Java;JavaScript;Objective-C;Swift
# 3948        Assembly;C;C#;C++;HTML/CSS;Java;JavaScript;PHP...
# ...                                                       ...
# 21657        Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;PHP
# 29429                              Bash/Shell/PowerShell;Ruby
# 44018       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;JavaSc...
# 5459                                            C#;JavaScript
# 58883                           C#;Java;JavaScript;Python;SQL
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 29260                      Apache Spark;Node.js;Unreal Engine
# 33865                                        Node.js;Teraform
# 16018                                       .NET Core;Node.js
# 193                                                       NaN
# 3948        Flutter;Hadoop;Node.js;React Native;TensorFlow...
# ...                                                       ...
# 21657                               .NET;.NET Core;TensorFlow
# 29429       Apache Spark;Hadoop;Keras;Pandas;TensorFlow;To...
# 44018       .NET;.NET Core;Flutter;Node.js;React Native;Te...
# 5459                                        .NET Core;Node.js
# 58883                                 .NET;.NET Core;Unity 3D
#
#                                            MiscTechWorkedWith  \
# Respondent
# 29260                                                 Node.js
# 33865                                        Node.js;Teraform
# 16018                                                     NaN
# 193                                                       NaN
# 3948        .NET;.NET Core;Cordova;Hadoop;Node.js;React Na...
# ...                                                       ...
# 21657                               .NET;.NET Core;TensorFlow
# 29429                                                     NaN
# 44018                                          .NET;.NET Core
# 5459                                                .NET Core
# 58883                                 .NET;.NET Core;Unity 3D
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 29260       Jira;Github;Gitlab;Microsoft Teams;Google Suit...
# 33865       Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 16018                                                  Github
# 193         Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 3948        Github;Gitlab;Microsoft Teams;Microsoft Azure;...
# ...                                                       ...
# 21657                                                     NaN
# 29429        Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# 44018             Jira;Github;Microsoft Teams;Microsoft Azure
# 5459                        Confluence;Github;Microsoft Azure
# 58883       Github;Google Suite (Docs, Meet, etc);Stack Ov...
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 29260       Jira;Github;Microsoft Teams;Google Suite (Docs...       Yes
# 33865       Confluence;Jira;Github;Slack;Trello;Google Sui...  Not sure
# 16018                                         Confluence;Jira  Not sure
# 193         Github;Gitlab;Slack;Microsoft Teams;Trello;Goo...        No
# 3948            Github;Gitlab;Microsoft Teams;Microsoft Azure       Yes
# ...                                                       ...       ...
# 21657                                                     NaN  Not sure
# 29429        Jira;Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 44018                      Jira;Github;Gitlab;Microsoft Teams        No
# 5459                                          Microsoft Azure        No
# 58883       Github;Microsoft Teams;Google Suite (Docs, Mee...  Not sure
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 29260        Somewhat important                      Very important
# 33865                   Neutral                  Somewhat important
# 16018                   Neutral                      Very important
# 193                     Neutral                    Fairly important
# 3948        Extremely important  Not at all important/not necessary
# ...                         ...                                 ...
# 21657                   Neutral                  Somewhat important
# 29429        Somewhat important                      Very important
# 44018       Extremely important                      Very important
# 5459        Extremely important                    Fairly important
# 58883       Extremely important                    Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 29260       Better work/life balance;Wanting to work with ...
# 33865       Better compensation;Trouble with my teammates;...
# 16018       Curious about other opportunities;Better compe...
# 193         Curious about other opportunities;Better compe...
# 3948        Curious about other opportunities;Growth or le...
# ...                                                       ...
# 21657       Trouble with my direct manager;Trouble with le...
# 29429       Just because;Curious about other opportunities...
# 44018       Wanting to share accomplishments with a wider ...
# 5459        Having a bad day (or week or month) at work;Wa...
# 58883       Having a bad day (or week or month) at work;Cu...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 29260       Read company media, such as employee blogs or ...
# 33865       Read company media, such as employee blogs or ...
# 16018       Company reviews from third party sites (e.g. G...
# 193         Read company media, such as employee blogs or ...
# 3948        Read company media, such as employee blogs or ...
# ...                                                       ...
# 21657       Read company media, such as employee blogs or ...
# 29429       Company reviews from third party sites (e.g. G...
# 44018       Read company media, such as employee blogs or ...
# 5459        Company reviews from third party sites (e.g. G...
# 58883       Company reviews from third party sites (e.g. G...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 29260                        NaN         Yes                            No
# 33865                Once a year    Not sure                            No
# 16018       Once every few years    Not sure                           Yes
# 193             Every few months          No  Onboarding? What onboarding?
# 3948                 Once a year    Not sure                           Yes
# ...                          ...         ...                           ...
# 21657       Once every few years          No                           Yes
# 29429                Once a year          No                            No
# 44018           Every few months    Not sure  Onboarding? What onboarding?
# 5459                 Once a year         NaN                            No
# 58883                Once a year          No                           Yes
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 29260                 No                   Often: 1-2 days per week or more
# 33865                Yes  Sometimes: 1-2 days per month but less than we...
# 16018                 No                                              Never
# 193                   No                                              Never
# 3948                 Yes                   Often: 1-2 days per week or more
# ...                  ...                                                ...
# 21657                 No  Sometimes: 1-2 days per month but less than we...
# 29429                 No  Sometimes: 1-2 days per month but less than we...
# 44018                 No                  Rarely: 1-2 days per year or less
# 5459                 Yes  Sometimes: 1-2 days per month but less than we...
# 58883                Yes                  Rarely: 1-2 days per year or less
#
#                                           NEWPurchaseResearch  \
# Respondent
# 29260       Start a free trial;Ask developers I know/work ...
# 33865                                                     NaN
# 16018                                                     NaN
# 193                                                       NaN
# 3948                                       Start a free trial
# ...                                                       ...
# 21657       Start a free trial;Ask developers I know/work ...
# 29429       Start a free trial;Ask developers I know/work ...
# 44018                                                     NaN
# 5459                                                      NaN
# 58883                                                     NaN
#
#                 NEWPurpleLink  \
# Respondent
# 29260             Indifferent
# 33865                  Amused
# 16018                  Amused
# 193         Hello, old friend
# 3948        Hello, old friend
# ...                       ...
# 21657       Hello, old friend
# 29429             Indifferent
# 44018             Indifferent
# 5459        Hello, old friend
# 58883                 Annoyed
#
#                                                    NEWSOSites  \
# Respondent
# 29260        Stack Overflow (public Q&A for anyone who codes)
# 33865       Stack Overflow (public Q&A for anyone who code...
# 16018       Stack Overflow (public Q&A for anyone who code...
# 193         Stack Overflow (public Q&A for anyone who code...
# 3948        Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 21657        Stack Overflow (public Q&A for anyone who codes)
# 29429       Stack Overflow (public Q&A for anyone who code...
# 44018       Stack Overflow (public Q&A for anyone who code...
# 5459        Stack Overflow (public Q&A for anyone who code...
# 58883       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 29260       Call a coworker or friend;Visit Stack Overflow...      Windows
# 33865       Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 16018       Call a coworker or friend;Visit Stack Overflow...      Windows
# 193         Play games;Visit Stack Overflow;Do other work ...        MacOS
# 3948        Visit Stack Overflow;Watch help / tutorial videos      Windows
# ...                                                       ...          ...
# 21657       Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 29429       Meditate;Call a coworker or friend;Visit Stack...        MacOS
# 44018       Meditate;Visit Stack Overflow;Go for a walk or...      Windows
# 5459        Visit Stack Overflow;Go for a walk or other ph...      Windows
# 58883       Meditate;Play games;Visit Stack Overflow;Go fo...      Windows
#
#                              OrgSize  \
# Respondent
# 29260       1,000 to 4,999 employees
# 33865           100 to 499 employees
# 16018       1,000 to 4,999 employees
# 193               10 to 19 employees
# 3948            500 to 999 employees
# ...                              ...
# 21657             10 to 19 employees
# 29429       1,000 to 4,999 employees
# 44018             20 to 99 employees
# 5459                             NaN
# 58883           100 to 499 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 29260       Android;AWS;Docker;Kubernetes;Linux;Microsoft ...
# 33865       Arduino;AWS;Docker;Kubernetes;Linux;MacOS;Slac...
# 16018                            iOS;Linux;MacOS;Raspberry Pi
# 193                                               Android;iOS
# 3948                 Kubernetes;Linux;Microsoft Azure;Windows
# ...                                                       ...
# 21657                                   Arduino;Linux;Windows
# 29429                Docker;Google Cloud Platform;Linux;MacOS
# 44018       AWS;Docker;Kubernetes;Linux;Microsoft Azure;Wi...
# 5459                           Docker;Microsoft Azure;Windows
# 58883              Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                            PlatformWorkedWith  \
# Respondent
# 29260         Docker;Kubernetes;Linux;Microsoft Azure;Windows
# 33865       Arduino;AWS;Docker;Kubernetes;Linux;MacOS;Slac...
# 16018                                            Docker;Linux
# 193                                               Android;iOS
# 3948        Android;Arduino;Docker;Google Cloud Platform;H...
# ...                                                       ...
# 21657                  Arduino;Docker;Linux;Windows;WordPress
# 29429                                             Linux;MacOS
# 44018                                    Docker;Linux;Windows
# 5459                                  Microsoft Azure;Windows
# 58883                    Android;Arduino;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 29260                  I have some influence  Straight / Heterosexual
# 33865          I have little or no influence  Straight / Heterosexual
# 16018          I have little or no influence  Straight / Heterosexual
# 193            I have little or no influence  Straight / Heterosexual
# 3948                   I have some influence  Straight / Heterosexual
# ...                                      ...                      ...
# 21657       I have a great deal of influence                      NaN
# 29429                  I have some influence  Straight / Heterosexual
# 44018          I have little or no influence  Straight / Heterosexual
# 5459           I have little or no influence  Straight / Heterosexual
# 58883          I have little or no influence  Straight / Heterosexual
#
#                           SOAccount           SOComm  \
# Respondent
# 29260                           Yes          Neutral
# 33865                           Yes    Yes, somewhat
# 16018                           Yes   No, not really
# 193                             Yes   No, not really
# 3948                            Yes    Yes, somewhat
# ...                             ...              ...
# 21657                           Yes         Not sure
# 29429                            No   No, not really
# 44018                           Yes  Yes, definitely
# 5459        Not sure/can't remember   No, not really
# 58883                           Yes  Yes, definitely
#
#                                                    SOPartFreq  \
# Respondent
# 29260       I have never participated in Q&A on Stack Over...
# 33865                         A few times per month or weekly
# 16018                     Less than once per month or monthly
# 193                       Less than once per month or monthly
# 3948                          A few times per month or weekly
# ...                                                       ...
# 21657                     Less than once per month or monthly
# 29429                                                     NaN
# 44018                                    A few times per week
# 5459                                                      NaN
# 58883                         A few times per month or weekly
#
#                                     SOVisitFreq                  SurveyEase  \
# Respondent
# 29260       Less than once per month or monthly                        Easy
# 33865                      A few times per week                        Easy
# 16018                     Daily or almost daily                        Easy
# 193                        A few times per week  Neither easy nor difficult
# 3948                      Daily or almost daily  Neither easy nor difficult
# ...                                         ...                         ...
# 21657                     Daily or almost daily                        Easy
# 29429                     Daily or almost daily  Neither easy nor difficult
# 44018                     Daily or almost daily                         NaN
# 5459                      Daily or almost daily  Neither easy nor difficult
# 58883                    Multiple times per day                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 29260       Appropriate in length    No
# 33865       Appropriate in length    No
# 16018                    Too long    No
# 193         Appropriate in length    No
# 3948        Appropriate in length    No
# ...                           ...   ...
# 21657       Appropriate in length    No
# 29429                    Too long    No
# 44018                         NaN    No
# 5459                     Too long    No
# 58883                   Too short    No
#
#                                                UndergradMajor  \
# Respondent
# 29260                               Mathematics or statistics
# 33865       Computer science, computer engineering, or sof...
# 16018       Computer science, computer engineering, or sof...
# 193         Computer science, computer engineering, or sof...
# 3948                                                      NaN
# ...                                                       ...
# 21657       Computer science, computer engineering, or sof...
# 29429       Computer science, computer engineering, or sof...
# 44018       Computer science, computer engineering, or sof...
# 5459        Information systems, information technology, o...
# 58883       Computer science, computer engineering, or sof...
#
#                              WebframeDesireNextYear  \
# Respondent
# 29260       Angular;ASP.NET;Express;jQuery;React.js
# 33865                                      React.js
# 16018                                  ASP.NET Core
# 193                                             NaN
# 3948                Angular;Express;React.js;Vue.js
# ...                                             ...
# 21657                          ASP.NET;ASP.NET Core
# 29429                                           NaN
# 44018           ASP.NET Core;jQuery;React.js;Vue.js
# 5459                          ASP.NET Core;React.js
# 58883                         ASP.NET Core;React.js
#
#                                            WebframeWorkedWith  \
# Respondent
# 29260                          Angular;ASP.NET;Express;jQuery
# 33865                                         React.js;Vue.js
# 16018                                                  jQuery
# 193                                                       NaN
# 3948        Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# ...                                                       ...
# 21657                                          ASP.NET;jQuery
# 29429                                           Ruby on Rails
# 44018                             ASP.NET;ASP.NET Core;jQuery
# 5459                            ASP.NET;ASP.NET Core;React.js
# 58883                         Angular.js;ASP.NET;ASP.NET Core
#
#                                       WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 29260       Just as welcome now as I felt last year         52.0        28
# 33865       Just as welcome now as I felt last year         40.0        20
# 16018       Just as welcome now as I felt last year         40.0         5
# 193         Just as welcome now as I felt last year         40.0        13
# 3948                                            NaN         40.0         6
# ...                                             ...          ...       ...
# 21657         A lot less welcome now than last year         60.0         7
# 29429       Just as welcome now as I felt last year         45.0        15
# 44018       Just as welcome now as I felt last year         40.0        20
# 5459                                            NaN         40.0        10
# 58883       Just as welcome now as I felt last year         40.0        12
#
#            YearsCodePro
# Respondent
# 29260                25
# 33865                15
# 16018                 1
# 193                   7
# 3948                  3
# ...                 ...
# 21657                 3
# 29429                10
# 44018                18
# 5459                 10
# 58883                 4
#
# [13178 rows x 60 columns]

# %%
df_survey.loc[filter_high_salary].sort_values(
    by='ConvertedComp', ascending=False).head(10)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 29260       I am a developer by profession      Yes  51.0         16   Weekly
# 33865       I am a developer by profession      Yes  35.0         15  Monthly
# 16018       I am a developer by profession      Yes  23.0         18   Weekly
# 193         I am a developer by profession      Yes  29.0         16   Weekly
# 3948        I am a developer by profession      Yes  25.0         18   Weekly
# 33787       I am a developer by profession      Yes  28.0         11   Weekly
# 4027        I am a developer by profession      Yes  29.0         16   Weekly
# 24097       I am a developer by profession       No  27.0         11   Weekly
# 33886       I am a developer by profession       No  24.0         18   Weekly
# 33745       I am a developer by profession       No  25.0         12   Weekly
#
#             CompTotal  ConvertedComp        Country          CurrencyDesc  \
# Respondent
# 29260        172000.0      2000000.0  United States  United States dollar
# 33865        250000.0      2000000.0  United States  United States dollar
# 16018         82000.0      2000000.0  United States  United States dollar
# 193          120000.0      2000000.0  United States  United States dollar
# 3948          70000.0      2000000.0  United States  United States dollar
# 33787        120000.0      2000000.0  United States  United States dollar
# 4027         120000.0      2000000.0  United States  United States dollar
# 24097        110000.0      2000000.0  United States  United States dollar
# 33886        110000.0      2000000.0  United States  United States dollar
# 33745         60000.0      2000000.0  United States  United States dollar
#
#            CurrencySymbol                             DatabaseDesireNextYear  \
# Respondent
# 29260                 USD  Elasticsearch;IBM DB2;Microsoft SQL Server;Mon...
# 33865                 USD                                      MongoDB;Redis
# 16018                 USD                                                NaN
# 193                   USD                                                NaN
# 3948                  USD                              MariaDB;MongoDB;Redis
# 33787                 USD  Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;...
# 4027                  USD  Elasticsearch;Microsoft SQL Server;MongoDB;MyS...
# 24097                 USD                                                NaN
# 33886                 USD                                            MariaDB
# 33745                 USD                            Firebase;MongoDB;SQLite
#
#                                            DatabaseWorkedWith  \
# Respondent
# 29260       IBM DB2;Microsoft SQL Server;MongoDB;MySQL;SQLite
# 33865                                MongoDB;PostgreSQL;Redis
# 16018                                        PostgreSQL;Redis
# 193                                                       NaN
# 3948        MariaDB;Microsoft SQL Server;MongoDB;MySQL;Ora...
# 33787       Cassandra;Microsoft SQL Server;MongoDB;MySQL;P...
# 4027        Elasticsearch;Microsoft SQL Server;MongoDB;MyS...
# 24097                                                     NaN
# 33886                                          MariaDB;SQLite
# 33745                                           MongoDB;MySQL
#
#                                                       DevType  \
# Respondent
# 29260       Designer;Developer, back-end;Developer, deskto...
# 33865       Developer, back-end;Developer, front-end;Devel...
# 16018                                     Developer, back-end
# 193                                         Developer, mobile
# 3948        Data or business analyst;Data scientist or mac...
# 33787       Data or business analyst;Data scientist or mac...
# 4027        Academic researcher;Data scientist or machine ...
# 24097       Developer, back-end;Developer, embedded applic...
# 33886                                   Developer, full-stack
# 33745                                    Developer, front-end
#
#                                                       EdLevel  \
# Respondent
# 29260            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33865            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16018            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 193           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3948        Secondary school (e.g. American high school, G...
# 33787            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4027             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24097            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33886            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33745            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                     Employment                     Ethnicity Gender  \
# Respondent
# 29260       Employed full-time  White or of European descent  Woman
# 33865       Employed full-time  White or of European descent    Man
# 16018       Employed full-time                           NaN    Man
# 193         Employed full-time  White or of European descent    Man
# 3948        Employed full-time  White or of European descent    Man
# 33787       Employed full-time  White or of European descent    Man
# 4027        Employed full-time  White or of European descent    Man
# 24097       Employed full-time  White or of European descent  Woman
# 33886       Employed full-time  White or of European descent    Man
# 33745       Employed full-time               Southeast Asian  Woman
#
#                                                    JobFactors  \
# Respondent
# 29260       Flex time or a flexible schedule;Languages, fr...
# 33865       Languages, frameworks, and other technologies ...
# 16018       Flex time or a flexible schedule;Remote work o...
# 193         Specific department or team I’d be working on;...
# 3948        Languages, frameworks, and other technologies ...
# 33787       Remote work options;Financial performance or f...
# 4027        Industry that I’d be working in;Flex time or a...
# 24097       How widely used or impactful my work output wo...
# 33886       Languages, frameworks, and other technologies ...
# 33745       Flex time or a flexible schedule;Remote work o...
#
#                                         JobSat  \
# Respondent
# 29260                           Very satisfied
# 33865                       Slightly satisfied
# 16018                       Slightly satisfied
# 193                             Very satisfied
# 3948                            Very satisfied
# 33787                           Very satisfied
# 4027        Neither satisfied nor dissatisfied
# 24097                        Very dissatisfied
# 33886                       Slightly satisfied
# 33745       Neither satisfied nor dissatisfied
#
#                                                       JobSeek  \
# Respondent
# 29260       I’m not actively looking, but I am open to new...
# 33865       I’m not actively looking, but I am open to new...
# 16018       I’m not actively looking, but I am open to new...
# 193         I’m not actively looking, but I am open to new...
# 3948        I’m not actively looking, but I am open to new...
# 33787       I’m not actively looking, but I am open to new...
# 4027        I’m not actively looking, but I am open to new...
# 24097       I’m not actively looking, but I am open to new...
# 33886       I’m not actively looking, but I am open to new...
# 33745       I’m not actively looking, but I am open to new...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 29260       Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 33865                                    Go;Python;TypeScript
# 16018                                         C#;Python;Swift
# 193                                         Objective-C;Swift
# 3948              Dart;Go;HTML/CSS;JavaScript;Rust;TypeScript
# 33787                                       C;Python;Rust;SQL
# 4027                         C#;C++;Go;Julia;Python;Scala;SQL
# 24097                                   Bash/Shell/PowerShell
# 33886       Bash/Shell/PowerShell;JavaScript;Python;Ruby;R...
# 33745                                     HTML/CSS;JavaScript
#
#                                            LanguageWorkedWith  \
# Respondent
# 29260       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 33865       Bash/Shell/PowerShell;Go;Java;JavaScript;Pytho...
# 16018                                                    Java
# 193                         Java;JavaScript;Objective-C;Swift
# 3948        Assembly;C;C#;C++;HTML/CSS;Java;JavaScript;PHP...
# 33787                                            C;Python;SQL
# 4027        Go;HTML/CSS;JavaScript;Julia;PHP;Python;R;Ruby...
# 24097                        Bash/Shell/PowerShell;TypeScript
# 33886       Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 33745                    C++;HTML/CSS;Java;JavaScript;PHP;SQL
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 29260                      Apache Spark;Node.js;Unreal Engine
# 33865                                        Node.js;Teraform
# 16018                                       .NET Core;Node.js
# 193                                                       NaN
# 3948        Flutter;Hadoop;Node.js;React Native;TensorFlow...
# 33787                                         Pandas;Teraform
# 4027        Apache Spark;Hadoop;Keras;Pandas;TensorFlow;To...
# 24097                                                     NaN
# 33886                                                 Node.js
# 33745                          Node.js;Unity 3D;Unreal Engine
#
#                                            MiscTechWorkedWith  \
# Respondent
# 29260                                                 Node.js
# 33865                                        Node.js;Teraform
# 16018                                                     NaN
# 193                                                       NaN
# 3948        .NET;.NET Core;Cordova;Hadoop;Node.js;React Na...
# 33787                                  Hadoop;Pandas;Teraform
# 4027        Apache Spark;Hadoop;Keras;Pandas;TensorFlow;To...
# 24097                                         Ansible;Node.js
# 33886                                   Node.js;Unreal Engine
# 33745                                                    .NET
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 29260       Jira;Github;Gitlab;Microsoft Teams;Google Suit...
# 33865       Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 16018                                                  Github
# 193         Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 3948        Github;Gitlab;Microsoft Teams;Microsoft Azure;...
# 33787                                           Github;Gitlab
# 4027              Github;Slack;Google Suite (Docs, Meet, etc)
# 24097        Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# 33886       Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 33745                                                     NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 29260       Jira;Github;Microsoft Teams;Google Suite (Docs...       Yes
# 33865       Confluence;Jira;Github;Slack;Trello;Google Sui...  Not sure
# 16018                                         Confluence;Jira  Not sure
# 193         Github;Gitlab;Slack;Microsoft Teams;Trello;Goo...        No
# 3948            Github;Gitlab;Microsoft Teams;Microsoft Azure       Yes
# 33787       Confluence;Jira;Github;Gitlab;Slack;Microsoft ...        No
# 4027        Jira;Github;Slack;Microsoft Teams;Trello;Googl...       Yes
# 24097       Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 33886       Github;Gitlab;Slack;Trello;Google Suite (Docs,...       Yes
# 33745                Jira;Github;Gitlab;Slack;Microsoft Teams  Not sure
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 29260        Somewhat important                      Very important
# 33865                   Neutral                  Somewhat important
# 16018                   Neutral                      Very important
# 193                     Neutral                    Fairly important
# 3948        Extremely important  Not at all important/not necessary
# 33787       Extremely important                    Fairly important
# 4027        Extremely important                  Somewhat important
# 24097        Somewhat important                    Fairly important
# 33886       Extremely important                      Very important
# 33745        Somewhat important                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 29260       Better work/life balance;Wanting to work with ...
# 33865       Better compensation;Trouble with my teammates;...
# 16018       Curious about other opportunities;Better compe...
# 193         Curious about other opportunities;Better compe...
# 3948        Curious about other opportunities;Growth or le...
# 33787       Wanting to work with new technologies;Growth o...
# 4027        Better compensation;Trouble with leadership at...
# 24097       Having a bad day (or week or month) at work;Wa...
# 33886                 Better compensation;Looking to relocate
# 33745       Better compensation;Better work/life balance;G...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 29260       Read company media, such as employee blogs or ...
# 33865       Read company media, such as employee blogs or ...
# 16018       Company reviews from third party sites (e.g. G...
# 193         Read company media, such as employee blogs or ...
# 3948        Read company media, such as employee blogs or ...
# 33787       Read company media, such as employee blogs or ...
# 4027        Read company media, such as employee blogs or ...
# 24097       Read company media, such as employee blogs or ...
# 33886       Read company media, such as employee blogs or ...
# 33745       Read company media, such as employee blogs or ...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 29260                        NaN         Yes                            No
# 33865                Once a year    Not sure                            No
# 16018       Once every few years    Not sure                           Yes
# 193             Every few months          No  Onboarding? What onboarding?
# 3948                 Once a year    Not sure                           Yes
# 33787                Once a year         NaN  Onboarding? What onboarding?
# 4027            Every few months    Not sure                            No
# 24097                Once a year    Not sure                            No
# 33886                Once a year          No                           Yes
# 33745       Once every few years    Not sure                           Yes
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 29260                 No                   Often: 1-2 days per week or more
# 33865                Yes  Sometimes: 1-2 days per month but less than we...
# 16018                 No                                              Never
# 193                   No                                              Never
# 3948                 Yes                   Often: 1-2 days per week or more
# 33787                Yes                   Often: 1-2 days per week or more
# 4027                  No                   Often: 1-2 days per week or more
# 24097                Yes  Occasionally: 1-2 days per quarter but less th...
# 33886                 No                                              Never
# 33745                 No                  Rarely: 1-2 days per year or less
#
#                                           NEWPurchaseResearch  \
# Respondent
# 29260       Start a free trial;Ask developers I know/work ...
# 33865                                                     NaN
# 16018                                                     NaN
# 193                                                       NaN
# 3948                                       Start a free trial
# 33787       Start a free trial;Ask developers I know/work ...
# 4027        Start a free trial;Ask developers I know/work ...
# 24097       Start a free trial;Ask developers I know/work ...
# 33886                                                     NaN
# 33745                                                     NaN
#
#                 NEWPurpleLink  \
# Respondent
# 29260             Indifferent
# 33865                  Amused
# 16018                  Amused
# 193         Hello, old friend
# 3948        Hello, old friend
# 33787             Indifferent
# 4027              Indifferent
# 24097       Hello, old friend
# 33886             Indifferent
# 33745                 Annoyed
#
#                                                    NEWSOSites  \
# Respondent
# 29260        Stack Overflow (public Q&A for anyone who codes)
# 33865       Stack Overflow (public Q&A for anyone who code...
# 16018       Stack Overflow (public Q&A for anyone who code...
# 193         Stack Overflow (public Q&A for anyone who code...
# 3948        Stack Overflow (public Q&A for anyone who code...
# 33787       Stack Overflow (public Q&A for anyone who code...
# 4027        Stack Overflow (public Q&A for anyone who code...
# 24097       Stack Overflow (public Q&A for anyone who code...
# 33886       Stack Overflow (public Q&A for anyone who code...
# 33745       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 29260       Call a coworker or friend;Visit Stack Overflow...      Windows
# 33865       Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 16018       Call a coworker or friend;Visit Stack Overflow...      Windows
# 193         Play games;Visit Stack Overflow;Do other work ...        MacOS
# 3948        Visit Stack Overflow;Watch help / tutorial videos      Windows
# 33787       Call a coworker or friend;Go for a walk or oth...  Linux-based
# 4027        Visit Stack Overflow;Go for a walk or other ph...      Windows
# 24097       Visit Stack Overflow;Panic;Watch help / tutori...  Linux-based
# 33886                                    Visit Stack Overflow        MacOS
# 33745       Call a coworker or friend;Panic;Do other work ...        MacOS
#
#                              OrgSize  \
# Respondent
# 29260       1,000 to 4,999 employees
# 33865           100 to 499 employees
# 16018       1,000 to 4,999 employees
# 193               10 to 19 employees
# 3948            500 to 999 employees
# 33787             20 to 99 employees
# 4027              20 to 99 employees
# 24097           500 to 999 employees
# 33886       1,000 to 4,999 employees
# 33745       10,000 or more employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 29260       Android;AWS;Docker;Kubernetes;Linux;Microsoft ...
# 33865       Arduino;AWS;Docker;Kubernetes;Linux;MacOS;Slac...
# 16018                            iOS;Linux;MacOS;Raspberry Pi
# 193                                               Android;iOS
# 3948                 Kubernetes;Linux;Microsoft Azure;Windows
# 33787       AWS;Docker;Google Cloud Platform;Kubernetes;Linux
# 4027         AWS;Docker;Google Cloud Platform;iOS;Linux;MacOS
# 24097                AWS;Docker;Kubernetes;Linux;Raspberry Pi
# 33886                                                     AWS
# 33745                     Docker;Google Cloud Platform;Heroku
#
#                                            PlatformWorkedWith  \
# Respondent
# 29260         Docker;Kubernetes;Linux;Microsoft Azure;Windows
# 33865       Arduino;AWS;Docker;Kubernetes;Linux;MacOS;Slac...
# 16018                                            Docker;Linux
# 193                                               Android;iOS
# 3948        Android;Arduino;Docker;Google Cloud Platform;H...
# 33787       AWS;Docker;Google Cloud Platform;Kubernetes;Linux
# 4027        AWS;Docker;Google Cloud Platform;Linux;MacOS;W...
# 24097                               Docker;Linux;Raspberry Pi
# 33886                                                     AWS
# 33745               AWS;Slack Apps and Integrations;WordPress
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 29260               I have some influence  Straight / Heterosexual       Yes
# 33865       I have little or no influence  Straight / Heterosexual       Yes
# 16018       I have little or no influence  Straight / Heterosexual       Yes
# 193         I have little or no influence  Straight / Heterosexual       Yes
# 3948                I have some influence  Straight / Heterosexual       Yes
# 33787               I have some influence  Straight / Heterosexual       Yes
# 4027                I have some influence  Straight / Heterosexual       Yes
# 24097               I have some influence                 Bisexual       Yes
# 33886       I have little or no influence  Straight / Heterosexual        No
# 33745       I have little or no influence  Straight / Heterosexual       Yes
#
#                     SOComm                                         SOPartFreq  \
# Respondent
# 29260              Neutral  I have never participated in Q&A on Stack Over...
# 33865        Yes, somewhat                    A few times per month or weekly
# 16018       No, not really                Less than once per month or monthly
# 193         No, not really                Less than once per month or monthly
# 3948         Yes, somewhat                    A few times per month or weekly
# 33787       No, not really                Less than once per month or monthly
# 4027               Neutral                Less than once per month or monthly
# 24097        Yes, somewhat                    A few times per month or weekly
# 33886       No, not really                                                NaN
# 33745       No, not really                               A few times per week
#
#                                     SOVisitFreq                  SurveyEase  \
# Respondent
# 29260       Less than once per month or monthly                        Easy
# 33865                      A few times per week                        Easy
# 16018                     Daily or almost daily                        Easy
# 193                        A few times per week  Neither easy nor difficult
# 3948                      Daily or almost daily  Neither easy nor difficult
# 33787                      A few times per week                        Easy
# 4027                      Daily or almost daily                        Easy
# 24097                      A few times per week                        Easy
# 33886           A few times per month or weekly  Neither easy nor difficult
# 33745                    Multiple times per day                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 29260       Appropriate in length    No
# 33865       Appropriate in length    No
# 16018                    Too long    No
# 193         Appropriate in length    No
# 3948        Appropriate in length    No
# 33787       Appropriate in length    No
# 4027        Appropriate in length    No
# 24097       Appropriate in length    No
# 33886       Appropriate in length    No
# 33745                    Too long    No
#
#                                                UndergradMajor  \
# Respondent
# 29260                               Mathematics or statistics
# 33865       Computer science, computer engineering, or sof...
# 16018       Computer science, computer engineering, or sof...
# 193         Computer science, computer engineering, or sof...
# 3948                                                      NaN
# 33787       Computer science, computer engineering, or sof...
# 4027        A social science (such as anthropology, psycho...
# 24097       Computer science, computer engineering, or sof...
# 33886       Computer science, computer engineering, or sof...
# 33745       Computer science, computer engineering, or sof...
#
#                              WebframeDesireNextYear  \
# Respondent
# 29260       Angular;ASP.NET;Express;jQuery;React.js
# 33865                                      React.js
# 16018                                  ASP.NET Core
# 193                                             NaN
# 3948                Angular;Express;React.js;Vue.js
# 33787                                           NaN
# 4027                                   Django;Flask
# 24097                                           NaN
# 33886                 jQuery;React.js;Ruby on Rails
# 33745             Angular;Angular.js;Express;Gatsby
#
#                                            WebframeWorkedWith  \
# Respondent
# 29260                          Angular;ASP.NET;Express;jQuery
# 33865                                         React.js;Vue.js
# 16018                                                  jQuery
# 193                                                       NaN
# 3948        Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 33787                                                     NaN
# 4027                                      Django;Flask;jQuery
# 24097                                      Angular;Angular.js
# 33886                           jQuery;React.js;Ruby on Rails
# 33745                                                 ASP.NET
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 29260        Just as welcome now as I felt last year         52.0        28
# 33865        Just as welcome now as I felt last year         40.0        20
# 16018        Just as welcome now as I felt last year         40.0         5
# 193          Just as welcome now as I felt last year         40.0        13
# 3948                                             NaN         40.0         6
# 33787        Just as welcome now as I felt last year         55.0        10
# 4027        Somewhat more welcome now than last year         45.0        10
# 24097        Just as welcome now as I felt last year         40.0         9
# 33886        Just as welcome now as I felt last year          NaN         5
# 33745       Somewhat less welcome now than last year         40.0         8
#
#            YearsCodePro
# Respondent
# 29260                25
# 33865                15
# 16018                 1
# 193                   7
# 3948                  3
# 33787                 3
# 4027                  6
# 24097                 5
# 33886                 1
# 33745                 3

# %%
# Rendezés fizetés és életkor szerint
df_survey.sort_values(by=['ConvertedComp', 'Age'], ascending=[False, True])
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 53443                          I am a developer by profession      Yes  20.0
# 58973       I am not primarily a developer, but I write co...       No  21.0
# 3620                           I am a developer by profession      Yes  22.0
# 4791                           I am a developer by profession      Yes  22.0
# 17900       I am not primarily a developer, but I write co...      Yes  22.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# 53443              18   Weekly    55000.0      2000000.0  United States
# 58973              15   Weekly    40000.0      2000000.0  United States
# 3620               14   Weekly    70000.0      2000000.0  United States
# 4791               14   Weekly    70000.0      2000000.0  United States
# 17900              15   Weekly    80000.0      2000000.0  United States
# ...               ...      ...        ...            ...            ...
# 64858              16      NaN        NaN            NaN  United States
# 64867             NaN      NaN        NaN            NaN        Morocco
# 64898             NaN      NaN        NaN            NaN       Viet Nam
# 64925             NaN      NaN        NaN            NaN         Poland
# 65112             NaN      NaN        NaN            NaN          Spain
#
#                     CurrencyDesc CurrencySymbol  \
# Respondent
# 53443       United States dollar            USD
# 58973       United States dollar            USD
# 3620        United States dollar            USD
# 4791        United States dollar            USD
# 17900       United States dollar            USD
# ...                          ...            ...
# 64858                        NaN            NaN
# 64867                        NaN            NaN
# 64898                        NaN            NaN
# 64925                        NaN            NaN
# 65112                        NaN            NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 53443       MariaDB;Microsoft SQL Server;MongoDB;MySQL;Ora...
# 58973                       Microsoft SQL Server;MySQL;SQLite
# 3620                                                      NaN
# 4791                                                      NaN
# 17900                                                DynamoDB
# ...                                                       ...
# 64858                                                     NaN
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                                                     NaN
# 64925         DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 65112                            MariaDB;Microsoft SQL Server
#
#                                            DatabaseWorkedWith  \
# Respondent
# 53443       Firebase;Microsoft SQL Server;MongoDB;MySQL;Or...
# 58973                                    Microsoft SQL Server
# 3620        IBM DB2;MariaDB;Microsoft SQL Server;MongoDB;M...
# 4791                                             Oracle;Redis
# 17900                                                DynamoDB
# ...                                                       ...
# 64858                                                     NaN
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                                                     NaN
# 64925                                                  Oracle
# 65112               MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                       DevType  \
# Respondent
# 53443       Developer, back-end;Developer, front-end;Devel...
# 58973                                                     NaN
# 3620                                    Developer, full-stack
# 4791        Developer, desktop or enterprise applications;...
# 17900       Database administrator;Developer, back-end;Dev...
# ...                                                       ...
# 64858                                     Senior executive/VP
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                                       EdLevel  \
# Respondent
# 53443       Secondary school (e.g. American high school, G...
# 58973            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3620        Some college/university study without earning ...
# 4791             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17900            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 64858         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64867                                                     NaN
# 64898                               Primary/elementary school
# 64925                                                     NaN
# 65112              Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                     Employment                     Ethnicity Gender  \
# Respondent
# 53443       Employed full-time        Hispanic or Latino/a/x    Man
# 58973       Employed full-time  White or of European descent    Man
# 3620        Employed full-time        Hispanic or Latino/a/x    Man
# 4791        Employed full-time  White or of European descent    Man
# 17900       Employed full-time  White or of European descent    Man
# ...                        ...                           ...    ...
# 64858       Employed full-time                           NaN    NaN
# 64867       Employed full-time                           NaN    NaN
# 64898                      NaN                           NaN    NaN
# 64925       Employed full-time                           NaN    NaN
# 65112       Employed full-time                           NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 53443       Languages, frameworks, and other technologies ...
# 58973       Specific department or team I’d be working on;...
# 3620        Remote work options;Office environment or comp...
# 4791        Flex time or a flexible schedule;Specific depa...
# 17900       Languages, frameworks, and other technologies ...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                         JobSat  \
# Respondent
# 53443       Neither satisfied nor dissatisfied
# 58973                        Very dissatisfied
# 3620                            Very satisfied
# 4791                     Slightly dissatisfied
# 17900                    Slightly dissatisfied
# ...                                        ...
# 64858                                      NaN
# 64867                                      NaN
# 64898                                      NaN
# 64925                                      NaN
# 65112                                      NaN
#
#                                                       JobSeek  \
# Respondent
# 53443                         I am actively looking for a job
# 58973                         I am actively looking for a job
# 3620             I am not interested in new job opportunities
# 4791        I’m not actively looking, but I am open to new...
# 17900                         I am actively looking for a job
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 53443        Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python
# 58973       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 3620                                                      NaN
# 4791        Bash/Shell/PowerShell;C#;Go;Haskell;HTML/CSS;J...
# 17900                                 Kotlin;Scala;TypeScript
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 53443               C#;HTML/CSS;Java;JavaScript;Kotlin;Python
# 58973                          C#;HTML/CSS;JavaScript;SQL;VBA
# 3620        Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 4791        Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 17900                              Java;JavaScript;TypeScript
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                                HTML/CSS
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                            MiscTechDesireNextYear  \
# Respondent
# 53443                Flutter;Node.js;React Native
# 58973              .NET;.NET Core;Node.js;Xamarin
# 3620        .NET;.NET Core;Unity 3D;Unreal Engine
# 4791                      .NET;.NET Core;Unity 3D
# 17900                            Node.js;Teraform
# ...                                           ...
# 64858                                         NaN
# 64867                                         NaN
# 64898                                         NaN
# 64925                                     Node.js
# 65112                           .NET Core;Xamarin
#
#                                            MiscTechWorkedWith  \
# Respondent
# 53443       .NET;.NET Core;Flutter;Node.js;React Native;Un...
# 58973                                          .NET;.NET Core
# 3620                                           Node.js;Pandas
# 4791                                  .NET;.NET Core;Unity 3D
# 17900                                        Node.js;Teraform
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                          .NET;.NET Core
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 53443       Github;Slack;Microsoft Azure;Google Suite (Doc...
# 58973                                       Jira;Github;Slack
# 3620                                                      NaN
# 4791                             Github;Slack;Microsoft Teams
# 17900                                Jira;Github;Slack;Trello
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                           Github;Gitlab
# 65112                                  Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 53443       Github;Slack;Microsoft Azure;Google Suite (Doc...        No
# 58973                                                    Jira        No
# 3620        Confluence;Jira;Github;Gitlab;Slack;Microsoft ...  Not sure
# 4791                                   Github;Microsoft Teams        No
# 17900                     Confluence;Jira;Github;Slack;Trello        No
# ...                                                       ...       ...
# 64858                                                     NaN       NaN
# 64867                                                     NaN       NaN
# 64898                                                     NaN       NaN
# 64925                   Confluence;Jira;Slack;Microsoft Teams       NaN
# 65112                                                  Github       NaN
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 53443       Extremely important                  Somewhat important
# 58973                   Neutral                    Fairly important
# 3620                    Neutral  Not at all important/not necessary
# 4791         Somewhat important                Critically important
# 17900       Extremely important                      Very important
# ...                         ...                                 ...
# 64858                       NaN                      Very important
# 64867                       NaN                                 NaN
# 64898                       NaN                                 NaN
# 64925                       NaN                                 NaN
# 65112                       NaN                Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 53443       Curious about other opportunities;Better work/...
# 58973       Having a bad day (or week or month) at work;Be...
# 3620        Better compensation;Better work/life balance;W...
# 4791        Having a bad day (or week or month) at work;Be...
# 17900       Just because;Having a bad day (or week or mont...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 53443       Company reviews from third party sites (e.g. G...
# 58973       Company reviews from third party sites (e.g. G...
# 3620        Read company media, such as employee blogs or ...
# 4791        Company reviews from third party sites (e.g. G...
# 17900       Read company media, such as employee blogs or ...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                     NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# Respondent
# 53443       Every few months    Not sure            Yes            No
# 58973            Once a year         NaN             No            No
# 3620        Every few months         Yes            Yes           Yes
# 4791        Every few months          No             No            No
# 17900       Every few months         Yes             No            No
# ...                      ...         ...            ...           ...
# 64858          Once a decade         NaN            NaN           NaN
# 64867                    NaN         NaN            NaN           NaN
# 64898                    NaN         NaN            NaN           NaN
# 64925            Once a year         NaN            NaN           NaN
# 65112            Once a year         NaN            NaN           NaN
#
#                                                   NEWOvertime  \
# Respondent
# 53443                       Rarely: 1-2 days per year or less
# 58973                        Often: 1-2 days per week or more
# 3620        Occasionally: 1-2 days per quarter but less th...
# 4791        Occasionally: 1-2 days per quarter but less th...
# 17900       Sometimes: 1-2 days per month but less than we...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 53443                                                     NaN
# 58973                                                     NaN
# 3620                                                      NaN
# 4791                                                      NaN
# 17900       Start a free trial;Ask developers I know/work ...
# ...                                                       ...
# 64858                                      Start a free trial
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                      Start a free trial
# 65112       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 53443       Hello, old friend
# 58973       Hello, old friend
# 3620        Hello, old friend
# 4791                  Annoyed
# 17900       Hello, old friend
# ...                       ...
# 64858                  Amused
# 64867                     NaN
# 64898                     NaN
# 64925       Hello, old friend
# 65112             Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 53443       Stack Overflow (public Q&A for anyone who code...
# 58973       Stack Overflow (public Q&A for anyone who code...
# 3620        Stack Overflow (public Q&A for anyone who code...
# 4791        Stack Overflow (public Q&A for anyone who code...
# 17900       Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64858        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
# 64898                                                     NaN
# 64925        Stack Overflow (public Q&A for anyone who codes)
# 65112                                                     NaN
#
#                                                      NEWStuck    OpSys  \
# Respondent
# 53443       Go for a walk or other physical activity;Do ot...    MacOS
# 58973                                    Visit Stack Overflow  Windows
# 3620        Visit Stack Overflow;Do other work and come ba...  Windows
# 4791        Play games;Call a coworker or friend;Visit Sta...  Windows
# 17900       Visit Stack Overflow;Watch help / tutorial vid...  Windows
# ...                                                       ...      ...
# 64858                               Call a coworker or friend  Windows
# 64867                                                     NaN      NaN
# 64898                                                     NaN      NaN
# 64925          Call a coworker or friend;Visit Stack Overflow  Windows
# 65112       Meditate;Visit Stack Overflow;Go for a walk or...  Windows
#
#                              OrgSize  \
# Respondent
# 53443             20 to 99 employees
# 58973             20 to 99 employees
# 3620              20 to 99 employees
# 4791        5,000 to 9,999 employees
# 17900       10,000 or more employees
# ...                              ...
# 64858                            NaN
# 64867                            NaN
# 64898                            NaN
# 64925                            NaN
# 65112                            NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 53443       Android;AWS;Google Cloud Platform;Heroku;iOS;L...
# 58973                                         Android;Windows
# 3620                                                      NaN
# 4791                                        Docker;Kubernetes
# 17900                                   AWS;Docker;Kubernetes
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                      Arduino;Linux;Raspberry Pi;Windows
#
#                                            PlatformWorkedWith  \
# Respondent
# 53443                       Microsoft Azure;Windows;WordPress
# 58973                                             AWS;Windows
# 3620        Android;Docker;Linux;MacOS;Raspberry Pi;Window...
# 4791                                           Docker;Windows
# 17900                         AWS;Slack Apps and Integrations
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                           Linux;Windows
# 65112              Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 53443          I have little or no influence  Straight / Heterosexual
# 58973          I have little or no influence  Straight / Heterosexual
# 3620           I have little or no influence  Straight / Heterosexual
# 4791           I have little or no influence  Straight / Heterosexual
# 17900       I have a great deal of influence                      NaN
# ...                                      ...                      ...
# 64858                                    NaN                      NaN
# 64867                                    NaN                      NaN
# 64898                                    NaN                      NaN
# 64925                                    NaN                      NaN
# 65112                                    NaN                      NaN
#
#                           SOAccount           SOComm  \
# Respondent
# 53443       Not sure/can't remember          Neutral
# 58973                            No   No, not at all
# 3620                            Yes  Yes, definitely
# 4791                            Yes   No, not really
# 17900                           Yes    Yes, somewhat
# ...                             ...              ...
# 64858                           NaN              NaN
# 64867                           NaN              NaN
# 64898                           NaN              NaN
# 64925                           NaN              NaN
# 65112                           NaN              NaN
#
#                                  SOPartFreq                      SOVisitFreq  \
# Respondent
# 53443                                   NaN  A few times per month or weekly
# 58973                                   NaN            Daily or almost daily
# 3620                  Daily or almost daily           Multiple times per day
# 4791        A few times per month or weekly           Multiple times per day
# 17900       A few times per month or weekly           Multiple times per day
# ...                                     ...                              ...
# 64858                                   NaN                              NaN
# 64867                                   NaN                              NaN
# 64898                                   NaN                              NaN
# 64925                                   NaN                              NaN
# 65112                                   NaN                              NaN
#
#            SurveyEase           SurveyLength Trans  \
# Respondent
# 53443            Easy  Appropriate in length    No
# 58973            Easy  Appropriate in length    No
# 3620             Easy              Too short    No
# 4791             Easy  Appropriate in length    No
# 17900            Easy               Too long    No
# ...               ...                    ...   ...
# 64858             NaN                    NaN   NaN
# 64867             NaN                    NaN   NaN
# 64898             NaN                    NaN   NaN
# 64925             NaN                    NaN   NaN
# 65112             NaN                    NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 53443                                                     NaN
# 58973       Information systems, information technology, o...
# 3620        Computer science, computer engineering, or sof...
# 4791        Computer science, computer engineering, or sof...
# 17900                               Mathematics or statistics
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 53443       Angular;Angular.js;Django;Express;Flask;React....
# 58973             ASP.NET;ASP.NET Core;React.js;Ruby on Rails
# 3620                                                      NaN
# 4791                                                 React.js
# 17900                                  Angular;Express;Spring
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                             Angular;Angular.js;React.js
# 65112                                     ASP.NET Core;jQuery
#
#                                            WebframeWorkedWith  \
# Respondent
# 53443       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 58973                                    ASP.NET;ASP.NET Core
# 3620              Django;Express;Flask;jQuery;React.js;Vue.js
# 4791                               Angular.js;React.js;Spring
# 17900                                  Angular;Express;Vue.js
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 53443        Just as welcome now as I felt last year         40.0         1
# 58973        Just as welcome now as I felt last year         45.0         5
# 3620         Just as welcome now as I felt last year         45.0         8
# 4791         Just as welcome now as I felt last year         40.0         8
# 17900       Somewhat more welcome now than last year         40.0         7
# ...                                              ...          ...       ...
# 64858                                            NaN          NaN        10
# 64867                                            NaN          NaN       NaN
# 64898                                            NaN          NaN       NaN
# 64925                                            NaN          NaN       NaN
# 65112                                            NaN          NaN       NaN
#
#                 YearsCodePro
# Respondent
# 53443                      1
# 58973                      2
# 3620                       2
# 4791        Less than 1 year
# 17900                      1
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
# Hiányzó értékek kezelése rendezéskor
df_survey.sort_values(by='ConvertedComp', ascending=False, na_position='last')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 18770       I am a developer by profession      Yes  31.0         19   Weekly
# 65527       I am a developer by profession      Yes   NaN         11  Monthly
# 18688       I am a developer by profession      Yes  25.0         21   Weekly
# 65502       I am a developer by profession      Yes   NaN         11   Weekly
# 42919       I am a developer by profession      Yes   NaN         15   Weekly
# ...                                    ...      ...   ...        ...      ...
# 64858                                  NaN      Yes   NaN         16      NaN
# 64867                                  NaN      Yes   NaN        NaN      NaN
# 64898                                  NaN      Yes   NaN        NaN      NaN
# 64925                                  NaN      Yes   NaN        NaN      NaN
# 65112                                  NaN      Yes   NaN        NaN      NaN
#
#             CompTotal  ConvertedComp        Country          CurrencyDesc  \
# Respondent
# 18770         75000.0      2000000.0  United States  United States dollar
# 65527        450000.0      2000000.0  United States  United States dollar
# 18688         90000.0      2000000.0  United States  United States dollar
# 65502         66000.0      2000000.0  United States  United States dollar
# 42919        135000.0      2000000.0  United States  United States dollar
# ...               ...            ...            ...                   ...
# 64858             NaN            NaN  United States                   NaN
# 64867             NaN            NaN        Morocco                   NaN
# 64898             NaN            NaN       Viet Nam                   NaN
# 64925             NaN            NaN         Poland                   NaN
# 65112             NaN            NaN          Spain                   NaN
#
#            CurrencySymbol                             DatabaseDesireNextYear  \
# Respondent
# 18770                 USD                                                NaN
# 65527                 USD                Firebase;IBM DB2;MongoDB;PostgreSQL
# 18688                 USD                                Firebase;PostgreSQL
# 65502                 USD                       Microsoft SQL Server;MongoDB
# 42919                 USD            Cassandra;Elasticsearch;MariaDB;MongoDB
# ...                   ...                                                ...
# 64858                 NaN                                                NaN
# 64867                 NaN  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                 NaN                                                NaN
# 64925                 NaN    DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 65112                 NaN                       MariaDB;Microsoft SQL Server
#
#                                            DatabaseWorkedWith  \
# Respondent
# 18770                                    Microsoft SQL Server
# 65527       DynamoDB;Firebase;Microsoft SQL Server;MongoDB...
# 18688                                                   MySQL
# 65502         MariaDB;Microsoft SQL Server;MongoDB;PostgreSQL
# 42919                                                   MySQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                                                     NaN
# 64925                                                  Oracle
# 65112               MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                       DevType  \
# Respondent
# 18770                                   Developer, full-stack
# 65527       Data scientist or machine learning specialist;...
# 18688       Developer, back-end;Developer, front-end;Devel...
# 65502       Database administrator;Developer, back-end;Dev...
# 42919       Developer, back-end;Developer, desktop or ente...
# ...                                                       ...
# 64858                                     Senior executive/VP
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                                       EdLevel  \
# Respondent
# 18770            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65527       Some college/university study without earning ...
# 18688       Some college/university study without earning ...
# 65502                     Associate degree (A.A., A.S., etc.)
# 42919            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 64858         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64867                                                     NaN
# 64898                               Primary/elementary school
# 64925                                                     NaN
# 65112              Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                                    Employment  \
# Respondent
# 18770                                      Employed full-time
# 65527                                      Employed part-time
# 18688                                      Employed full-time
# 65502                                      Employed full-time
# 42919       Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 64858                                      Employed full-time
# 64867                                      Employed full-time
# 64898                                                     NaN
# 64925                                      Employed full-time
# 65112                                      Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 18770       White or of European descent    Man
# 65527                                NaN    NaN
# 18688       White or of European descent    Man
# 65502                                NaN    NaN
# 42919                                NaN    NaN
# ...                                  ...    ...
# 64858                                NaN    NaN
# 64867                                NaN    NaN
# 64898                                NaN    NaN
# 64925                                NaN    NaN
# 65112                                NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 18770       Flex time or a flexible schedule;Remote work o...
# 65527       Industry that I’d be working in;Remote work op...
# 18688       Diversity of the company or organization;How w...
# 65502       Flex time or a flexible schedule;Specific depa...
# 42919       Flex time or a flexible schedule;Financial per...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                         JobSat  \
# Respondent
# 18770                           Very satisfied
# 65527       Neither satisfied nor dissatisfied
# 18688                    Slightly dissatisfied
# 65502       Neither satisfied nor dissatisfied
# 42919                           Very satisfied
# ...                                        ...
# 64858                                      NaN
# 64867                                      NaN
# 64898                                      NaN
# 64925                                      NaN
# 65112                                      NaN
#
#                                                       JobSeek  \
# Respondent
# 18770            I am not interested in new job opportunities
# 65527       I’m not actively looking, but I am open to new...
# 18688                         I am actively looking for a job
# 65502            I am not interested in new job opportunities
# 42919       I’m not actively looking, but I am open to new...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 18770                                              Rust;Swift
# 65527       HTML/CSS;JavaScript;Kotlin;Python;Ruby;SQL;Typ...
# 18688                                                      C#
# 65502                                          C#;Perl;Python
# 42919                                   C#;Go;Rust;TypeScript
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 18770                   C#;HTML/CSS;JavaScript;SQL;TypeScript
# 65527       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 18688                             HTML/CSS;JavaScript;PHP;SQL
# 65502       C#;HTML/CSS;JavaScript;Perl;Python;SQL;TypeScript
# 42919                                             Go;Java;SQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                                HTML/CSS
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                 MiscTechDesireNextYear  \
# Respondent
# 18770                      TensorFlow;Teraform;Xamarin
# 65527                                              NaN
# 18688                     .NET Core;Flutter;TensorFlow
# 65502                                .NET Core;Node.js
# 42919       .NET Core;Apache Spark;Hadoop;React Native
# ...                                                ...
# 64858                                              NaN
# 64867                                              NaN
# 64898                                              NaN
# 64925                                          Node.js
# 65112                                .NET Core;Xamarin
#
#                         MiscTechWorkedWith  \
# Respondent
# 18770                       .NET;.NET Core
# 65527                                  NaN
# 18688                         React Native
# 65502       .NET;.NET Core;Node.js;Xamarin
# 42919                                  NaN
# ...                                    ...
# 64858                                  NaN
# 64867                                  NaN
# 64898                                  NaN
# 64925                                  NaN
# 65112                       .NET;.NET Core
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 18770                                          NaN
# 65527                                          NaN
# 18688                                          NaN
# 65502       Github;Microsoft Teams;Microsoft Azure
# 42919                                          NaN
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                Github;Gitlab
# 65112                       Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 18770       Github;Microsoft Teams;Microsoft Azure;Trello;...        No
# 65527                                                     NaN       Yes
# 18688                                                  Github        No
# 65502       Confluence;Jira;Github;Microsoft Teams;Microso...  Not sure
# 42919                                                     NaN        No
# ...                                                       ...       ...
# 64858                                                     NaN       NaN
# 64867                                                     NaN       NaN
# 64898                                                     NaN       NaN
# 64925                   Confluence;Jira;Slack;Microsoft Teams       NaN
# 65112                                                  Github       NaN
#
#                   NEWDevOpsImpt             NEWEdImpt  \
# Respondent
# 18770       Extremely important      Fairly important
# 65527        Somewhat important      Fairly important
# 18688                       NaN      Fairly important
# 65502        Somewhat important        Very important
# 42919       Extremely important      Fairly important
# ...                         ...                   ...
# 64858                       NaN        Very important
# 64867                       NaN                   NaN
# 64898                       NaN                   NaN
# 64925                       NaN                   NaN
# 65112                       NaN  Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 18770       Better compensation;Trouble with my teammates;...
# 65527       Having a bad day (or week or month) at work;Wa...
# 18688       Wanting to share accomplishments with a wider ...
# 65502       Just because;Having a bad day (or week or mont...
# 42919       Curious about other opportunities;Better compe...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 18770       Read company media, such as employee blogs or ...
# 65527       Company reviews from third party sites (e.g. G...
# 18688       Company reviews from third party sites (e.g. G...
# 65502       Read company media, such as employee blogs or ...
# 42919       Company reviews from third party sites (e.g. G...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 18770                Once a year    Not sure                           Yes
# 65527       Once every few years         Yes                           Yes
# 18688           Every few months          No  Onboarding? What onboarding?
# 65502                Once a year          No  Onboarding? What onboarding?
# 42919                Once a year    Not sure  Onboarding? What onboarding?
# ...                          ...         ...                           ...
# 64858              Once a decade         NaN                           NaN
# 64867                        NaN         NaN                           NaN
# 64898                        NaN         NaN                           NaN
# 64925                Once a year         NaN                           NaN
# 65112                Once a year         NaN                           NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 18770                 No  Occasionally: 1-2 days per quarter but less th...
# 65527                 No                  Rarely: 1-2 days per year or less
# 18688                Yes                   Often: 1-2 days per week or more
# 65502                 No  Sometimes: 1-2 days per month but less than we...
# 42919                 No  Occasionally: 1-2 days per quarter but less th...
# ...                  ...                                                ...
# 64858                NaN                                                NaN
# 64867                NaN                                                NaN
# 64898                NaN                                                NaN
# 64925                NaN                                                NaN
# 65112                NaN                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 18770       Start a free trial;Ask developers I know/work ...
# 65527                                                     NaN
# 18688       Ask developers I know/work with;Visit develope...
# 65502                                                     NaN
# 42919                                                     NaN
# ...                                                       ...
# 64858                                      Start a free trial
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                      Start a free trial
# 65112       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 18770       Hello, old friend
# 65527                     NaN
# 18688       Hello, old friend
# 65502                 Annoyed
# 42919                     NaN
# ...                       ...
# 64858                  Amused
# 64867                     NaN
# 64898                     NaN
# 64925       Hello, old friend
# 65112             Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 18770       Stack Overflow (public Q&A for anyone who code...
# 65527       Stack Overflow (public Q&A for anyone who code...
# 18688       Stack Overflow (public Q&A for anyone who code...
# 65502       Stack Overflow (public Q&A for anyone who code...
# 42919       Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64858        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
# 64898                                                     NaN
# 64925        Stack Overflow (public Q&A for anyone who codes)
# 65112                                                     NaN
#
#                                                      NEWStuck    OpSys  \
# Respondent
# 18770       Call a coworker or friend;Visit Stack Overflow...  Windows
# 65527                                                     NaN      NaN
# 18688       Visit Stack Overflow;Watch help / tutorial vid...  Windows
# 65502       Meditate;Visit Stack Overflow;Go for a walk or...  Windows
# 42919                                                     NaN      NaN
# ...                                                       ...      ...
# 64858                               Call a coworker or friend  Windows
# 64867                                                     NaN      NaN
# 64898                                                     NaN      NaN
# 64925          Call a coworker or friend;Visit Stack Overflow  Windows
# 65112       Meditate;Visit Stack Overflow;Go for a walk or...  Windows
#
#                              OrgSize  \
# Respondent
# 18770             20 to 99 employees
# 65527           100 to 499 employees
# 18688               2 to 9 employees
# 65502           100 to 499 employees
# 42919       10,000 or more employees
# ...                              ...
# 64858                            NaN
# 64867                            NaN
# 64898                            NaN
# 64925                            NaN
# 65112                            NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 18770                                                     NaN
# 65527       Android;AWS;Google Cloud Platform;IBM Cloud or...
# 18688                                                     NaN
# 65502                            Microsoft Azure;Raspberry Pi
# 42919       Android;AWS;Docker;iOS;Kubernetes;MacOS;Raspbe...
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                      Arduino;Linux;Raspberry Pi;Windows
#
#                                     PlatformWorkedWith  \
# Respondent
# 18770                                  Microsoft Azure
# 65527       Android;AWS;Heroku;Microsoft Azure;Windows
# 18688                                            Linux
# 65502             Microsoft Azure;Raspberry Pi;Windows
# 42919                             Docker;Linux;Windows
# ...                                                ...
# 64858                                              NaN
# 64867                                              NaN
# 64898                                              NaN
# 64925                                    Linux;Windows
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 18770                  I have some influence  Straight / Heterosexual
# 65527                                    NaN                      NaN
# 18688       I have a great deal of influence  Straight / Heterosexual
# 65502          I have little or no influence                      NaN
# 42919                                    NaN                      NaN
# ...                                      ...                      ...
# 64858                                    NaN                      NaN
# 64867                                    NaN                      NaN
# 64898                                    NaN                      NaN
# 64925                                    NaN                      NaN
# 65112                                    NaN                      NaN
#
#                           SOAccount          SOComm  \
# Respondent
# 18770                           Yes  No, not really
# 65527                           Yes         Neutral
# 18688                           Yes   Yes, somewhat
# 65502                           Yes   Yes, somewhat
# 42919       Not sure/can't remember         Neutral
# ...                             ...             ...
# 64858                           NaN             NaN
# 64867                           NaN             NaN
# 64898                           NaN             NaN
# 64925                           NaN             NaN
# 65112                           NaN             NaN
#
#                                      SOPartFreq  \
# Respondent
# 18770                      A few times per week
# 65527       Less than once per month or monthly
# 18688                     Daily or almost daily
# 65502                      A few times per week
# 42919                                       NaN
# ...                                         ...
# 64858                                       NaN
# 64867                                       NaN
# 64898                                       NaN
# 64925                                       NaN
# 65112                                       NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 18770                Multiple times per day  Neither easy nor difficult
# 65527       A few times per month or weekly                         NaN
# 18688                Multiple times per day                        Easy
# 65502                Multiple times per day                         NaN
# 42919                 Daily or almost daily                         NaN
# ...                                     ...                         ...
# 64858                                   NaN                         NaN
# 64867                                   NaN                         NaN
# 64898                                   NaN                         NaN
# 64925                                   NaN                         NaN
# 65112                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 18770                    Too long    No
# 65527                         NaN   NaN
# 18688       Appropriate in length    No
# 65502                         NaN   NaN
# 42919                         NaN   NaN
# ...                           ...   ...
# 64858                         NaN   NaN
# 64867                         NaN   NaN
# 64898                         NaN   NaN
# 64925                         NaN   NaN
# 65112                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 18770       Computer science, computer engineering, or sof...
# 65527       Information systems, information technology, o...
# 18688                                I never declared a major
# 65502       Computer science, computer engineering, or sof...
# 42919       Computer science, computer engineering, or sof...
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 18770                                                     NaN
# 65527       Angular;Django;Express;React.js;Ruby on Rails;...
# 18688                                            ASP.NET Core
# 65502                               ASP.NET Core;Flask;Vue.js
# 42919                                                 Angular
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                             Angular;Angular.js;React.js
# 65112                                     ASP.NET Core;jQuery
#
#                                            WebframeWorkedWith  \
# Respondent
# 18770            Angular;ASP.NET;ASP.NET Core;jQuery;React.js
# 65527                    Django;Express;Flask;React.js;Spring
# 18688                                                React.js
# 65502       ASP.NET;ASP.NET Core;Express;Flask;Gatsby;Reac...
# 42919                                                  Spring
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                       WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 18770       Just as welcome now as I felt last year         40.0        11
# 65527       Just as welcome now as I felt last year         60.0        14
# 18688       Just as welcome now as I felt last year         40.0         6
# 65502       Just as welcome now as I felt last year         40.0         5
# 42919       Just as welcome now as I felt last year         42.0        13
# ...                                             ...          ...       ...
# 64858                                           NaN          NaN        10
# 64867                                           NaN          NaN       NaN
# 64898                                           NaN          NaN       NaN
# 64925                                           NaN          NaN       NaN
# 65112                                           NaN          NaN       NaN
#
#                 YearsCodePro
# Respondent
# 18770                      9
# 65527                      3
# 18688                      5
# 65502                      3
# 42919                      6
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
df_survey.loc[filter_high_salary, ['Country', 'ConvertedComp']].sort_values(
    by='ConvertedComp', ascending=False).head(10)
# Out:
#                   Country  ConvertedComp
# Respondent
# 29260       United States      2000000.0
# 33865       United States      2000000.0
# 16018       United States      2000000.0
# 193         United States      2000000.0
# 3948        United States      2000000.0
# 33787       United States      2000000.0
# 4027        United States      2000000.0
# 24097       United States      2000000.0
# 33886       United States      2000000.0
# 33745       United States      2000000.0

# %%
filter_hungary = df_survey['Country'] == 'Hungary'

# %%
df_survey.loc[filter_hungary, ['Age', 'DevType', 'LanguageWorkedWith', 'ConvertedComp']].sort_values(
    by='ConvertedComp', ascending=False).head(30)
# Out:
#              Age                                            DevType  \
# Respondent
# 54198       38.0  Data or business analyst;Data scientist or mac...
# 46816        NaN  Developer, back-end;Developer, full-stack;Educ...
# 17411       37.0  Developer, back-end;Developer, front-end;Devel...
# 13612        NaN                              Developer, full-stack
# 7033        22.0                                  Developer, mobile
# 16126       44.0  Academic researcher;Data or business analyst;D...
# 59482       33.0                                Developer, back-end
# 50680       29.0            Developer, full-stack;Developer, mobile
# 13242       35.0  Developer, back-end;Developer, desktop or ente...
# 12431       38.0                              Developer, full-stack
# 48454       27.0                                Developer, back-end
# 21968       41.0                                Developer, back-end
# 34534       40.0  Developer, back-end;Developer, desktop or ente...
# 35232       30.0  Developer, back-end;Developer, front-end;Devel...
# 34639       33.0  Developer, back-end;Developer, desktop or ente...
# 23559       41.0  Developer, back-end;Developer, front-end;Devel...
# 31002       27.0         Developer, front-end;Developer, full-stack
# 15603       34.0  Developer, back-end;Developer, front-end;Devel...
# 13343       40.0  Developer, back-end;Developer, desktop or ente...
# 12991       38.0  Database administrator;Developer, back-end;Dev...
# 5350        43.0  Designer;Developer, back-end;Developer, deskto...
# 56115       34.0  Data or business analyst;Database administrato...
# 1346        22.0  Developer, back-end;Developer, desktop or ente...
# 59428       34.0  Developer, back-end;Developer, desktop or ente...
# 15940       34.0  Data scientist or machine learning specialist;...
# 18579       36.0  Developer, back-end;Developer, full-stack;DevO...
# 25166       27.0  Developer, back-end;Developer, embedded applic...
# 12350        NaN  Developer, back-end;Developer, front-end;Devel...
# 8844        36.0                                Developer, back-end
# 45167        NaN                                  Developer, mobile
#
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 54198       Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...       250000.0
# 46816                                                     NaN       230916.0
# 17411                            HTML/CSS;JavaScript;Ruby;SQL       135123.0
# 13612                            C#;JavaScript;SQL;TypeScript       129720.0
# 7033                                        Objective-C;Swift       124800.0
# 16126                      Bash/Shell/PowerShell;Julia;Python       111341.0
# 59482                Dart;HTML/CSS;Java;JavaScript;Kotlin;SQL        90804.0
# 50680       Dart;HTML/CSS;JavaScript;Kotlin;Objective-C;Py...        90000.0
# 13242                                Assembly;Java;Python;SQL        78912.0
# 12431                     Go;HTML/CSS;JavaScript;Python;Scala        76971.0
# 48454                                          C++;Python;SQL        76968.0
# 21968                                                Java;SQL        75000.0
# 34534       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...        71196.0
# 35232                                                    Java        69276.0
# 34639                       C#;HTML/CSS;JavaScript;TypeScript        69276.0
# 23559                                  C#;HTML/CSS;Python;SQL        69276.0
# 31002                 HTML/CSS;JavaScript;PHP;Ruby;TypeScript        69183.0
# 15603                                         HTML/CSS;Kotlin        65425.0
# 13343                    Bash/Shell/PowerShell;C++;Java;Scala        65424.0
# 12991             HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript        64150.0
# 5350                                   C#;HTML/CSS;TypeScript        64143.0
# 56115       HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript;VBA        64143.0
# 1346                    C#;HTML/CSS;JavaScript;SQL;TypeScript        64000.0
# 59428       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;JavaSc...        57732.0
# 15940       Bash/Shell/PowerShell;C#;Go;HTML/CSS;JavaScrip...        55907.0
# 18579       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...        55800.0
# 25166                                             Go;Java;SQL        53880.0
# 12350       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Kotl...        53880.0
# 8844                         Bash/Shell/PowerShell;JavaScript        53496.0
# 45167       C#;HTML/CSS;Java;JavaScript;Kotlin;Swift;TypeS...        53184.0

# %%
filter_python = df_survey['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df_survey.loc[filter_python, 'LanguageWorkedWith'].sort_values(
    ascending=False).head(10).str.split(';').str[0].value_counts().head(10)
# Out:
# LanguageWorkedWith
# Python    10
# Name: count, dtype: int64
